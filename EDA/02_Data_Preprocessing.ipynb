# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../Data/raw/creditcard.csv")

print("Dataset loaded successfully.")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully.
# Shape: (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
print("Total missing values:", df.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
numeric_columns = df.select_dtypes(include=np.number).columns

print(
    "Total infinite values:",
    np.isinf(df[numeric_columns]).sum().sum()
)
# Out:
# Total infinite values: 0

# %%
duplicate_count = df.duplicated().sum()

print("Duplicate rows:", duplicate_count)
# Out:
# Duplicate rows: 1081

# %%
duplicate_rows = df[df.duplicated(keep=False)]

print(duplicate_rows["Class"].value_counts())
# Out:
# Class
# 0    1822
# 1      32
# Name: count, dtype: int64

# %%
print("Class distribution among duplicate rows:")
print(duplicate_rows["Class"].value_counts())
# Out:
# Class distribution among duplicate rows:
# Class
# 0    1822
# 1      32
# Name: count, dtype: int64

# %%
print("\nPercentage:")
print(
    duplicate_rows["Class"]
    .value_counts(normalize=True)
    .mul(100)
)
# Out:
# Percentage:
# Class
# 0    98.274002
# 1     1.725998
# Name: proportion, dtype: float64

# %%
print("Target column: Class")
print("\nUnique values:")
print(df["Class"].unique())

print("\nClass distribution:")
print(df["Class"].value_counts())
# Out:
# Target column: Class
#
# Unique values:
# [0 1]
#
# Class distribution:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
print("\nClass percentage:")
print(
    df["Class"]
    .value_counts(normalize=True)
    .mul(100)
)
# Out:
# Class percentage:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
print("Shape before removing duplicates:", df.shape)

df = df.drop_duplicates().reset_index(drop=True)

print("Shape after removing duplicates:", df.shape)
print("Duplicates remaining:", df.duplicated().sum())
# Out:
# Shape before removing duplicates: (284807, 31)
# Shape after removing duplicates: (283726, 31)
# Duplicates remaining: 0

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (283726, 30)
# y shape: (283726,)

# %%
print("Features:")
print(X.columns.tolist())

print("\nTarget:")
print(y.name)
# Out:
# Features:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']
#
# Target:
# Class

# %%
print(y.value_counts())
print("\nPercentage:")
print(y.value_counts(normalize=True) * 100)
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64
#
# Percentage:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

# %%
# Save original training and test data

X_train.to_csv("../Data/processed/X_train.csv", index=False)
y_train.to_csv("../Data/processed/y_train.csv", index=False)

# X_test and y_test are already saved, so no need to save them again

print("Original training data saved successfully.")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
# Out:
# Original training data saved successfully.
# X_train: (198608, 30)
# y_train: (198608,)

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (198608, 30)
# X_test : (85118, 30)
# y_train: (198608,)
# y_test : (85118,)

# %%
print("Training set:")
print(y_train.value_counts())
print(y_train.value_counts(normalize=True) * 100)

print("\nTesting set:")
print(y_test.value_counts())
print(y_test.value_counts(normalize=True) * 100)
# Out:
# Training set:
# Class
# 0    198277
# 1       331
# Name: count, dtype: int64
# Class
# 0    99.83334
# 1     0.16666
# Name: proportion, dtype: float64
#
# Testing set:
# Class
# 0    84976
# 1      142
# Name: count, dtype: int64
# Class
# 0    99.833173
# 1     0.166827
# Name: proportion, dtype: float64

# %%
scaler = StandardScaler()

# %%
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

X_train_scaled[["Time", "Amount"]] = scaler.fit_transform(
    X_train[["Time", "Amount"]]
)

X_test_scaled[["Time", "Amount"]] = scaler.transform(
    X_test[["Time", "Amount"]]
)

# %%
print("Training set:")
print(X_train_scaled[["Time", "Amount"]].describe().loc[["mean", "std"]])

print("\nTesting set:")
print(X_test_scaled[["Time", "Amount"]].describe().loc[["mean", "std"]])
# Out:
# Training set:
#               Time        Amount
# mean -6.246514e-17 -9.602316e-17
# std   1.000003e+00  1.000003e+00
#
# Testing set:
#           Time    Amount
# mean -0.007356  0.002075
# std   0.999675  1.103357

# %%
print("Training class distribution:")
print(y_train.value_counts())

print("\nTraining class percentage:")
print(y_train.value_counts(normalize=True) * 100)
# Out:
# Training class distribution:
# Class
# 0    198277
# 1       331
# Name: count, dtype: int64
#
# Training class percentage:
# Class
# 0    99.83334
# 1     0.16666
# Name: proportion, dtype: float64

# %%
class_counts = y_train.value_counts()

imbalance_ratio = class_counts[0] / class_counts[1]

print("Genuine transactions:", class_counts[0])
print("Fraudulent transactions:", class_counts[1])
print("Imbalance ratio:", round(imbalance_ratio, 2))
# Out:
# Genuine transactions: 198277
# Fraudulent transactions: 331
# Imbalance ratio: 599.02

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train_scaled,
    y_train
)

# %%
print("Before SMOTE:")
print(y_train.value_counts())

print("\nAfter SMOTE:")
print(y_train_smote.value_counts())
# Out:
# Before SMOTE:
# Class
# 0    198277
# 1       331
# Name: count, dtype: int64
#
# After SMOTE:
# Class
# 0    198277
# 1    198277
# Name: count, dtype: int64

# %%
print("Original training shape:", X_train.shape)
print("SMOTE training shape:", X_train_smote.shape)

print("Original target shape:", y_train.shape)
print("SMOTE target shape:", y_train_smote.shape)
# Out:
# Original training shape: (198608, 30)
# SMOTE training shape: (396554, 30)
# Original target shape: (198608,)
# SMOTE target shape: (396554,)

# %%
print("Missing values:")
print(X_train_smote.isnull().sum().sum())

print("\nInfinite values:")
print(np.isinf(X_train_smote).sum().sum())
# Out:
# Missing values:
# 0
#
# Infinite values:
# 0

# %%
print("Number of features:", X_train_smote.shape[1])
print("\nFeatures:")
print(X_train_smote.columns.tolist())
# Out:
# Number of features: 30
#
# Features:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# %%
print(y_train_smote.value_counts())
# Out:
# Class
# 0    198277
# 1    198277
# Name: count, dtype: int64

# %%
print("Test set shape:", X_test_scaled.shape)

print("\nTest class distribution:")
print(y_test.value_counts())

print("\nTest class percentages:")
print(y_test.value_counts(normalize=True) * 100)
# Out:
# Test set shape: (85118, 30)
#
# Test class distribution:
# Class
# 0    84976
# 1      142
# Name: count, dtype: int64
#
# Test class percentages:
# Class
# 0    99.833173
# 1     0.166827
# Name: proportion, dtype: float64

# %%
print("Final training data:")
print("X_train_smote:", X_train_smote.shape)
print("y_train_smote:", y_train_smote.shape)

print("\nFinal test data:")
print("X_test_scaled:", X_test_scaled.shape)
print("y_test:", y_test.shape)
# Out:
# Final training data:
# X_train_smote: (396554, 30)
# y_train_smote: (396554,)
#
# Final test data:
# X_test_scaled: (85118, 30)
# y_test: (85118,)

# %%
print("Training missing values:",
      X_train_smote.isnull().sum().sum())

print("Training infinite values:",
      np.isinf(X_train_smote).sum().sum())

print("\nTest missing values:",
      X_test_scaled.isnull().sum().sum())

print("Test infinite values:",
      np.isinf(X_test_scaled).sum().sum())
# Out:
# Training missing values: 0
# Training infinite values: 0
#
# Test missing values: 0
# Test infinite values: 0

# %%
import joblib

joblib.dump(scaler, "../models/scaler.pkl")

print("Scaler saved successfully.")
# Out:
# Scaler saved successfully.

# %%
import os

os.makedirs("../Data/processed", exist_ok=True)

# %%
X_train_smote.to_csv(
    "../Data/processed/X_train_smote.csv",
    index=False
)

y_train_smote.to_csv(
    "../Data/processed/y_train_smote.csv",
    index=False
)

X_test_scaled.to_csv(
    "../Data/processed/X_test.csv",
    index=False
)

y_test.to_csv(
    "../Data/processed/y_test.csv",
    index=False
)

print("Processed datasets saved successfully.")
# Out:
# Processed datasets saved successfully.

# %%
# # Preprocessing Summary

# ## Data Cleaning
# - The original dataset was loaded without modifying the raw CSV.
# - Exact duplicate rows were identified and removed.
# - Missing and infinite values were verified.

# ## Feature and Target Separation
# - `Class` was separated as the target variable.
# - `Time`, `V1`–`V28`, and `Amount` were used as input features.

# ## Train-Test Split
# - The data was divided into 80% training and 20% testing data.
# - Stratified splitting was used because of severe class imbalance.

# ## Feature Scaling
# - `Time` and `Amount` were standardized.
# - The scaler was fitted only on the training data and then applied to the test data.
# - The fitted scaler was saved for future inference.

# ## Class Imbalance
# - The dataset contains a severe imbalance between genuine and fraudulent transactions.
# - SMOTE was applied only to the training data.
# - The test set retained the original class distribution.

# ## Final Training Data
# - The SMOTE training dataset contains balanced classes.
# - The test dataset remains representative of the original distribution.

# ## Preprocessing Output
# The processed datasets were saved for model development and evaluation.
